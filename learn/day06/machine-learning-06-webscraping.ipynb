# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
requests.get(https://stackoverflow.com/questions?page=1).text

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

requests.get(https://stackoverflow.com/questions?page=1, headers=headers).text

# This is a huge website, they have good security reasons to block us, lets find some other website with lower security risks

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'} 
webpage = requests.get('https://www.ksolves.com/blog/artificial-intelligence/best-companies-in-india',headers=headers).text

# %%
webpage

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %%
print(soup.prettify())

# %%
soup.find_all('h2')[0]
