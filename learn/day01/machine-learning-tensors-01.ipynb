# %%
import numpy as np

# %%
# 0 Dimensional tensor
a = np.array(1)

# %%
a.ndim

# %%
# 1 Dimentional tensor, 4D vector

b = np.array([1,2, 3, 4])

# %%
b.ndim

# %%
# 1 Dimentional tensor, 3D vector

b = np.array([1,2, 3])

# %%
b.ndim

# %%
# 2 Dimentional tensor, 6D vector

c = np.array([[1, 2, 3],[4, 5, 6]])

# %%
c.ndim

# %%
# 3 Dimentional tensor, 3D vector

d = np.array([
    [[1, 2, 3],
    [1, 2, 3],
    [1, 2, 3]]
])

# %%
d.ndim
