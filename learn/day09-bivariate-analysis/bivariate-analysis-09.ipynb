# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = pd.read_csv("/kaggle/input/datasets/sanjanbm/modified-titanic-data/train.csv")
titanic.sample(5)
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 434          435         0       1         Silvey, Mr. William Baird    male
# 236          237         0       2                 Hold, Mr. Stephen    male
# 743          744         0       3                 McNamee, Mr. Neal    male
# 15            16         1       2  Hewlett, Mrs. (Mary D Kingcome)   female
# 656          657         0       3             Radeff, Mr. Alexander    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 434  50.0      1      0   13507  55.9000   E44        S
# 236  44.0      1      0   26707  26.0000   NaN        S
# 743  24.0      1      0  376566  16.1000   NaN        S
# 15   55.0      0      0  248706  16.0000   NaN        S
# 656   NaN      0      0  349223   7.8958   NaN        S

# %%
tips = sns.load_dataset('tips')
tips.sample(5)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 209       12.76  2.23  Female    Yes  Sat  Dinner     2
# 182       45.35  3.50    Male    Yes  Sun  Dinner     3
# 37        16.93  3.07  Female     No  Sat  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 219       30.14  3.09  Female    Yes  Sat  Dinner     4

# %%
flights = sns.load_dataset('flights')
flights.sample(5)
# Out:
#      year month  passengers
# 108  1958   Jan         340
# 28   1951   May         172
# 113  1958   Jun         435
# 74   1955   Mar         267
# 48   1953   Jan         196

# %%
iris = pd.read_csv("/kaggle/input/datasets/utkisironman/irirs-1/Iris (2).csv")
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 58    59            6.6           2.9            4.6           1.3
# 141  142            6.9           3.1            5.1           2.3
# 125  126            7.2           3.2            6.0           1.8
# 45    46            4.8           3.0            1.4           0.3
# 118  119            7.7           2.6            6.9           2.3
#
#              Species
# 58   Iris-versicolor
# 141   Iris-virginica
# 125   Iris-virginica
# 45       Iris-setosa
# 118   Iris-virginica

# %% [markdown]
# ## 1. ScatterPlot (Numeric - Numeric)

# %%
sns.scatterplot(x=tips['total_bill'], y=tips['tip'], hue = tips['sex'])
# the data is linear
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips['sex'].value_counts().plot(kind='pie', auto)
# Out:
# <Axes: ylabel='count'>

# %%
# This is multivariate analysis

sns.scatterplot(x=tips['total_bill'], y=tips['tip'], hue = tips['sex'], style=tips['smoker'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x=tips['total_bill'], y=tips['tip'], hue = tips['sex'], style=tips['smoker'], size=tips['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ## 2. BarPlot (Numeric - Categorical)

# %%
sns.barplot(x = titanic['Pclass'],y = titanic['Age'], hue = titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x = titanic['Pclass'], y = titanic['Fare'], hue = titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(x = titanic['Pclass'], y = titanic['Fare'], hue = titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %% [markdown]
# ## 3. BoxPlot (Numeric - Categorical)

# %%
sns.boxplot(x = titanic['Sex'], y = titanic['Age'], hue = titanic['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.boxplot(x = titanic['Sex'], y = titanic['Age'], hue = titanic['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %% [markdown]
# ## 4. DistPlot (Numeric - Categorical)

# %%
sns.distplot(x = titanic['Age'])
# Out:
# /tmp/ipykernel_55/512892630.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = titanic['Age'])
# <Axes: ylabel='Density'>

# %%
sns.distplot(titanic[titanic['Survived'] == 0]['Age'])
sns.distplot(titanic[titanic['Survived'] == 1]['Age'])
# Out:
# /tmp/ipykernel_55/1902325983.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived'] == 0]['Age'])
# /tmp/ipykernel_55/1902325983.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived'] == 1]['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(titanic[titanic['Survived'] == 0]['Age'], hist=False)
sns.distplot(titanic[titanic['Survived'] == 1]['Age'], hist=False)
# Out:
# /tmp/ipykernel_55/7298082.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived'] == 0]['Age'], hist=False)
# /tmp/ipykernel_55/7298082.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived'] == 1]['Age'], hist=False)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## 5. HeatMap (Categorical - Categorical)

# %%
titanic.sample(3)
# Out:
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 859          860         0       3         Razi, Mr. Raihed  male   NaN
# 466          467         0       2    Campbell, Mr. William  male   NaN
# 6              7         0       1  McCarthy, Mr. Timothy J  male  54.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked
# 859      0      0    2629   7.2292   NaN        C
# 466      0      0  239853   0.0000   NaN        S
# 6        0      0   17463  51.8625   E46        S

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'], titanic['Survived']))

# Information about the two categorical columns
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
titanic.groupby('Pclass').mean(numeric_only=True)['Survived']*100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
(titanic.groupby('Pclass').mean(numeric_only=True)['Survived']*100).plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
titanic.groupby('Sex').mean(numeric_only=True)['Survived']*100
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
(titanic.groupby('Sex').mean(numeric_only=True)['Survived']*100).plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# ## 6. ClusterMap (Categorical - Categorical)

# %%
pd.crosstab(titanic['SibSp'], titanic['Survived'])
# Out:
# Survived    0    1
# SibSp
# 0         398  210
# 1          97  112
# 2          15   13
# 3          12    4
# 4          15    3
# 5           5    0
# 8           7    0

# %%
sns.clustermap(pd.crosstab(titanic['SibSp'], titanic['Survived']))

# %%
pd.crosstab(titanic['Parch'], titanic['Survived'])
# Out:
# Survived    0    1
# Parch
# 0         445  233
# 1          53   65
# 2          40   40
# 3           2    3
# 4           4    0
# 5           4    1
# 6           1    0

# %%
sns.clustermap(pd.crosstab(titanic['Parch'], titanic['Survived']))

# %% [markdown]
# ## 7. Pairplot
# collection of scatterplot

# %%
iris.sample(3)
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 21  22            5.1           3.7            1.5           0.4
# 18  19            5.7           3.8            1.7           0.3
# 81  82            5.5           2.4            3.7           1.0
#
#             Species
# 21      Iris-setosa
# 18      Iris-setosa
# 81  Iris-versicolor

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue='Species')

# %% [markdown]
# ## 8. Lineplot (Numerical - Numerical)
# ths is to be used when there is time

# %%
flights.sample(5)
# Out:
#     year month  passengers
# 11  1949   Dec         118
# 82  1955   Nov         237
# 86  1956   Mar         317
# 1   1949   Feb         118
# 96  1957   Jan         315

# %%
flights.groupby('year').sum(numeric_only=True)
# Out:
#       passengers
# year
# 1949        1520
# 1950        1676
# 1951        2042
# 1952        2364
# 1953        2700
# 1954        2867
# 1955        3408
# 1956        3939
# 1957        4421
# 1958        4572
# 1959        5140
# 1960        5714

# %%
flights.groupby('year').sum(numeric_only=True).reset_index()
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
df = flights.groupby('year').sum(numeric_only=True).reset_index()

# %%
sns.lineplot(x = df['year'], y = df['passengers'])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
flights.pivot_table(values = 'passengers', index='month', columns='year')
# Out:
# /tmp/ipykernel_55/2061953298.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights.pivot_table(values = 'passengers', index='month', columns='year')
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# Dec    118.0  140.0  166.0  194.0  201.0  229.0  278.0  306.0  336.0  337.0
#
# year    1959   1960
# month
# Jan    360.0  417.0
# Feb    342.0  391.0
# Mar    406.0  419.0
# Apr    396.0  461.0
# May    420.0  472.0
# Jun    472.0  535.0
# Jul    548.0  622.0
# Aug    559.0  606.0
# Sep    463.0  508.0
# Oct    407.0  461.0
# Nov    362.0  390.0
# Dec    405.0  432.0

# %%
sns.heatmap(flights.pivot_table(values = 'passengers', index='month', columns='year'))
# Out:
# /tmp/ipykernel_55/108048773.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flights.pivot_table(values = 'passengers', index='month', columns='year'))
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(flights.pivot_table(values = 'passengers', index='month', columns='year'))
# Out:
# /tmp/ipykernel_55/1638635641.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.clustermap(flights.pivot_table(values = 'passengers', index='month', columns='year'))
