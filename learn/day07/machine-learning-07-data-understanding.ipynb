# %%
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/datasets/sanjanbm/titanic-dataset/train.csv')

# %% [markdown]
# ### 1. How big is the dataset

# %%
df.shape

# %% [markdown]
# ### 2. How the data looks like

# %%
df.head()

# %%
df.sample(5)

# %% [markdown]
# ### 3. what is the datatype of the columns

# %%
df.info()

# %% [markdown]
# ### 4. Are there any missing values in the dataset

# %%
df.isnull().sum()

# %% [markdown]
# ### 5. How does the data look mathematically

# %%
df.describe()

# %% [markdown]
# ### 6. Are there any duplicate values in the dataset

# %%
df.duplicated().sum()

# %% [markdown]
# ### 7. How is the correlation between the columns

# %%
df.corr(numeric_only=True)

# %%
df.corr(numeric_only=True)['Survived']
