# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/kaggle/input/datasets/sanjanbm/weight-height-dataset/weight-height.csv')
df.head()

# %%
df.shape

# %%
df['Height'].describe()

# %%
sns.distplot(df['Height'])

# %%
sns.boxplot(df['Height'])

# %%
# calculating upper percentile

upper_limit = df['Height'].quantile(0.99)
upper_limit

# quantile is specified in readme, can know more about it there

# %%
# calculating lower percentile

lower_limit = df['Height'].quantile(0.01)
lower_limit

# %%
new_df = df[(df['Height'] <= 74.78) & (df['Height'] >= 58.13)]

# %%
new_df['Height'].describe()

# %%
df['Height'].describe()

# %%
sns.distplot(new_df['Height'])

# %%
sns.boxplot(new_df['Height'])

# %%
# Capping --> Winsorization
df['Height'] = np.where(df['Height'] >= upper_limit,
        upper_limit,
        np.where(df['Height'] <= lower_limit,
        lower_limit,
        df['Height']))


df.shape

# %%
df['Height'].describe()

# %%
sns.boxplot(df['Height'])
