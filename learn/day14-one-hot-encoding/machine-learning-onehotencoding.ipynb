# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/kaggle/input/datasets/sanjanbm/cars-dataset/cars.csv")

df.sample(5)

# %%
df.shape

# %%
df['brand'].value_counts()

# %%
df['brand'].nunique()

# %%
df['fuel'].value_counts()

# %%
df['owner'].value_counts()

# %%
pd.get_dummies(df, columns = ['fuel', 'owner'], dtype=int)

# %% [markdown]
# ## 2. K-1 OneHotEncoding

# %%
pd.get_dummies(df, columns=['fuel','owner'], dtype=int, drop_first=True)

# %% [markdown]
# ## 3. OneHotEncoding using Sklearn(best method)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,0:4],df.iloc[:,-1],random_state=42, test_size=0.3)

X_train.shape, X_test.shape

# %%
from sklearn.preprocessing import OneHotEncoder

ohe = OneHotEncoder()

X_train_new = ohe.fit_transform(X_train[['fuel','owner']])

X_test_new = ohe.transform(X_test[['fuel','owner']])

# %%
X_train_new.shape

# %%
X_train[['brand','km_driven']].values

# %%
np.hstack((X_train[['brand','km_driven']].values, X_train_new.toarray())).shape

# %% [markdown]
# ## 4. OneHotEncoding with Top Categories

# %%
df['brand'].value_counts()

# %%
counts = df['brand'].value_counts()

# %%
df['brand'].nunique()
threshold = 100

# %%
counts[counts <= threshold].index

# %%
repl = counts[counts <= threshold].index

# %%
pd.get_dummies(df['brand'].replace(repl, 'uncommon'), dtype=int).sample(5)
