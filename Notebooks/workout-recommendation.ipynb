# %% [markdown]
# # Personalized Workout and Diet Recommendation
# This notebook provides a system to recommend personalized workout and diet plans based on user input and a dataset of gym users.
#
# ## Usage
# - Update the data file path to your local Excel file.
# - Provide user input as a dictionary to the `get_recommendation` function.
# - The function returns a list of recommended plans.
#
# ## Example
# ```python
# user_input = {
#     'Sex': 1,
#     'Age': 25,
#     'Height': 1.75,
#     'Weight': 70,
#     'Hypertension': 0,
#     'Diabetes': 0,
#     'BMI': 22.9,
#     'Level': 0,
#     'Fitness Goal': 1,
#     'Fitness Type': 0
# }
# recommendations = get_recommendation(user_input, top_n=3)
# for idx, rec in enumerate(recommendations, 1):
#     print(f'Recommendation {idx}:', rec)
# ```
