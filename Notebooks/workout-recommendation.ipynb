# %% [markdown]
# ## Data File Path
# Update the following variable to point to your local Excel file with the gym recommendation data.
#
# Example: `data_path = 'data/gym_recommendation.xlsx'`

# %%
# Set your local data file path here
data_path = 'data/gym_recommendation.xlsx'  # Update this path as needed
data = pd.read_excel(data_path)
